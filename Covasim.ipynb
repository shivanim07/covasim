# %%
#pip install covasim

# %%
import covasim as cv
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Covasim 3.1.6 (2024-01-28) — © 2020-2024 by IDM

# %%
sim = cv.Sim()

# %%
sim.run()
# Out:
# Initializing sim with 20000 people for 60 days
#   Running 2020-03-01 ( 0/60) (0.26 s)  ———————————————————— 2%
#   Running 2020-03-11 (10/60) (0.31 s)  •••————————————————— 18%
#   Running 2020-03-21 (20/60) (0.36 s)  ••••••—————————————— 34%
#   Running 2020-03-31 (30/60) (0.42 s)  ••••••••••—————————— 51%
#   Running 2020-04-10 (40/60) (0.48 s)  •••••••••••••——————— 67%
#   Running 2020-04-20 (50/60) (0.55 s)  ••••••••••••••••———— 84%
#   Running 2020-04-30 (60/60) (0.64 s)  •••••••••••••••••••• 100%
#
# Simulation summary:
#        12,730 cumulative infections
#           596 cumulative reinfections
#        10,182 cumulative infectious
#         6,395 cumulative symptomatic cases
#           386 cumulative severe cases
#           114 cumulative critical cases
#         5,159 cumulative recoveries
#            14 cumulative deaths
#             0 cumulative tests
#             0 cumulative diagnoses
#             0 cumulative known deaths
# ...

# %%
sim.plot()
